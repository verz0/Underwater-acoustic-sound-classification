# %%
# !pip install spafe
import os
import numpy as np
from scipy.io.wavfile import read
from scipy.signal import resample
from spafe.features.gfcc import gfcc
from spafe.utils.preprocessing import SlidingWindow
from spafe.utils.vis import show_features
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Collecting spafe
#   Downloading spafe-0.3.2-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.10/site-packages (from spafe) (1.26.4)
# Requirement already satisfied: scipy>=1.7.3 in /opt/conda/lib/python3.10/site-packages (from spafe) (1.11.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from spafe) (4.9.0)
# Downloading spafe-0.3.2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 2.2 MB/s eta 0:00:0000:01
# Installing collected packages: spafe
# Successfully installed spafe-0.3.2

# %%
input_folder = "/kaggle/input/tanker/Tanker"
output_folder = "/kaggle/working/tanker_GTCC"

# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read
from spafe.features.gfcc import gfcc
from spafe.utils.preprocessing import SlidingWindow
from spafe.utils.vis import show_features
from PIL import Image

def process_audio_file(audio_file, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(64, 43)):
    fs, y = read(audio_file)

    segment_samples = int(segment_length * sr)
    hop_samples = int(hop_length * sr)

    base_filename = os.path.splitext(os.path.basename(audio_file))[0]
    file_output_folder = os.path.join(output_folder, base_filename)
    os.makedirs(file_output_folder, exist_ok=True)

    for i in range(0, len(y), segment_samples):
        segment = y[i:i + segment_samples]
        if len(segment) < segment_samples:
            break
        gfccs  = gfcc(segment,
                      fs=sr,
                      pre_emph=1,
                      pre_emph_coeff=0.97,
                      window=SlidingWindow(frame_length, hop_length, "hamming"),
                      nfilts=128,
                      nfft=2048,
                      low_freq=0,
                      high_freq=8000,
                      normalize="mvn")
        
        fig, ax = plt.subplots(nrows=1, sharex=True, sharey=True)
        img = ax.imshow(gfccs.T, aspect='auto', origin='lower')
        ax.set(title=f'Segment {i//segment_samples + 1}')
        ax.axis('off')
        
        temp_filename = "temp.png"
        fig.savefig(temp_filename, bbox_inches='tight', pad_inches=0)
        plt.close(fig)
        
        with Image.open(temp_filename) as img:
            img = img.resize(target_size, Image.ANTIALIAS)
            output_filename = os.path.join(file_output_folder, f"{base_filename}_segment_{i//segment_samples + 1}.png")
            img.save(output_filename)
        
        os.remove(temp_filename)

def process_folder(input_folder, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(64, 43)):
    os.makedirs(output_folder, exist_ok=True)

    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):
            audio_file = os.path.join(input_folder, filename)
            process_audio_file(audio_file, output_folder, sr, segment_length, frame_length, hop_length, target_size)

process_folder(input_folder, output_folder)
# Out:
# /tmp/ipykernel_34/4269311977.py:53: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)

# %%
# !zip -r Tanker_GTCC.zip /kaggle/working/tanker_GTCC
# Out:
#   adding: kaggle/working/tanker_GTCC/ (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/ (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_6.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_10.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_2.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_4.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_3.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_9.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_8.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_5.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_7.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/21/21_segment_1.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/ (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_15.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_66.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_43.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_44.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_13.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_8.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_16.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_5.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_72.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_11.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_1.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_55.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_41.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_18.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_71.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_35.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_33.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_31.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_21.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_19.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_42.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_28.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_7.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_45.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_12.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_69.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_64.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_24.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_48.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_14.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_23.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_9.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_70.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_68.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_61.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_2.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_52.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_10.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_26.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_27.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_65.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_50.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_6.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_53.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_3.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_57.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_30.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_60.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_46.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_37.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_34.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_38.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_54.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_25.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_40.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_49.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_56.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_39.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_36.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_47.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_62.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_67.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_20.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_63.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_51.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_22.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_58.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_59.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_17.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_29.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_4.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/29/29_segment_32.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/ (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_28.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_4.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_26.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_38.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_9.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_15.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_14.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_3.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment_30.png (stored 0%)
#   adding: kaggle/working/tanker_GTCC/42/42_segment