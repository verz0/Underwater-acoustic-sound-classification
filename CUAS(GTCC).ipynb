# %%
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %ls
# Out:
#  41.wav       archive.zip         customCNN/   smoke/
#  9.wav       'CUAS(GTCC).ipynb'   fire/        Untitled0.ipynb
#  ANPR/        CUAS.ipynb          mfccs.csv    Untitled1.ipynb
#  ANPR.ipynb  'CUAS(MFCC).ipynb'   ResNet/      YOLOv8-Fire-and-Smoke-Detection/

# %%
# !pip install spafe
# Out:
# Collecting spafe
#   Downloading spafe-0.3.2-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from spafe) (1.25.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from spafe) (1.11.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from spafe) (4.10.0)
# Installing collected packages: spafe
# Successfully installed spafe-0.3.2

# %%
from scipy.io.wavfile import read
from spafe.features.gfcc import gfcc
from spafe.utils.preprocessing import SlidingWindow
from spafe.utils.vis import show_features

fpath = "9.wav"
fs, sig = read(fpath)

gfccs  = gfcc(sig,
              fs=fs,
              pre_emph=1,
              pre_emph_coeff=0.97,
              window=SlidingWindow(0.03, 0.015, "hamming"),
              nfilts=128,
              nfft=2048,
              low_freq=0,
              high_freq=8000,
              normalize="mvn")

show_features(gfccs, "Gammatone Frequency Cepstral Coefﬁcients", "GFCC Index", "Frame Index")
