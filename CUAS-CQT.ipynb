# %%
# !pip install librosa
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)

# %%
input_folder = "/kaggle/input/tanker/Tanker"
output_folder = "/kaggle/working/Tanker-CQT"

# %%
# !mkdir Tanker-CQT

# %%
# Function to process an audio file and save its chroma CQT segments as images
def process_audio_file(audio_file, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(64, 43)):
    # Load and resample the audio file
    y, original_sr = librosa.load(audio_file, sr=sr)
    
    # Calculate the number of samples per segment
    segment_samples = int(segment_length * sr)
    hop_samples = int(hop_length * sr)
    
    # Create output folder for the file if it doesn't exist
    base_filename = os.path.splitext(os.path.basename(audio_file))[0]
    file_output_folder = os.path.join(output_folder, base_filename)
    os.makedirs(file_output_folder, exist_ok=True)
    
    # Slice the audio into segments and process each segment
    for i in range(0, len(y), segment_samples):
        segment = y[i:i + segment_samples]
        if len(segment) < segment_samples:
            break  # Ignore short segments
        
        # Extract chroma CQT features for each frame in the segment
        chroma_cq = librosa.feature.chroma_cqt(y=segment, sr=sr, hop_length=hop_samples, n_chroma=12)
        
        # Plot chroma CQT without displaying it
        fig, ax = plt.subplots(nrows=1, sharex=True, sharey=True)
        img = librosa.display.specshow(chroma_cq, y_axis='chroma', x_axis='time', ax=ax, sr=sr, hop_length=hop_samples)
        ax.set(title=f'Segment {i//segment_samples + 1}')
        
        # Remove axes for cleaner image
        ax.axis('off')
        
        # Save the figure to a temporary file
        temp_filename = "temp.png"
        fig.savefig(temp_filename, bbox_inches='tight', pad_inches=0)
        plt.close(fig)
        
        # Open the saved image, resize it, and save it again
        with Image.open(temp_filename) as img:
            img = img.resize(target_size, Image.ANTIALIAS)
            output_filename = os.path.join(file_output_folder, f"{base_filename}_segment_{i//segment_samples + 1}.png")
            img.save(output_filename)
        
        # Remove the temporary file
        os.remove(temp_filename)

# Function to process a folder of audio files
def process_folder(input_folder, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(64, 43)):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)
    
    # Process each .wav file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):
            audio_file = os.path.join(input_folder, filename)
            process_audio_file(audio_file, output_folder, sr, segment_length, frame_length, hop_length, target_size)

# %%
process_folder(input_folder, output_folder)
# Out:
# /tmp/ipykernel_33/1921580381.py:39: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)
# /opt/conda/lib/python3.10/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
import shutil

# %%
shutil.rmtree("/kaggle/working/Tanker-CQT")

# %%
# !zip -r Tanker_CQT.zip /kaggle/working/Tanker-CQT
# Out:
#   adding: kaggle/working/Tanker-CQT/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/47/47_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/33_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/33_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/33_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/33_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/33/33_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/32/32_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/43/43_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_47.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_38.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_44.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_46.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_51.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_56.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_45.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_41.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_57.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_43.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_54.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_58.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_52.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_42.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_50.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_55.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_37.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_49.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_53.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_40.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_48.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/38/38_segment_39.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/48/48_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/18/18_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/41/41_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/8/8_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/20/20_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/21_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/21_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/21_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/21_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/21/21_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/35_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/35_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/35_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/35_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/35/35_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/24/24_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_50.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_45.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_37.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_42.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_40.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_43.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_38.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_44.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_47.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_41.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_49.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_39.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_48.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_46.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/2/2_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_48.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_52.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_46.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_44.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_37.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_41.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_47.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_51.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_56.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_38.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_42.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_55.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_40.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_49.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_45.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_54.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_43.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_39.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_57.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_50.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_53.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/6/6_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/30/30_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/42/42_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/5/5_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/9/9_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/49/49_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/14/14_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/50/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/50/50_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/50/50_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/50/50_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_40.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_41.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_39.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_43.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_37.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_42.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_38.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/39/39_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/19/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/19/19_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/19/19_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/19/19_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/19/19_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_41.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_33.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_50.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_42.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_39.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_48.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_43.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_49.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_45.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_44.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_52.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_37.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_51.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_46.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_38.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_40.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_47.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/13/13_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/ (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_12.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_15.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_9.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_4.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_20.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_22.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_30.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_36.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_19.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_7.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_18.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_28.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_21.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_13.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_5.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_31.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_29.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_6.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_10.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_24.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_25.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_2.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_16.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_11.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_14.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_26.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_8.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_17.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_34.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_32.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_3.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_23.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_27.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_1.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_35.png (stored 0%)
#   adding: kaggle/working/Tanker-CQT/29/29_segment_33.png (stored 0%)
