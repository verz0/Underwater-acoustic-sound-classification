# %%
# !pip install librosa
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)

# %%
input_folder = "/kaggle/input/tanker/Tanker"
output_folder = "/kaggle/working/Tanker-CEPSTRUM"

# %%
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
from PIL import Image

def extract_cepstrum(segment, sr=16000, frame_length=0.25, hop_length=0.064):
    # Compute the Short-Time Fourier Transform (STFT)
    S = np.abs(librosa.stft(segment, n_fft=int(sr*frame_length), hop_length=int(sr*hop_length)))

    # Compute the power spectrum
    power_spectrum = S**2

    # Compute the log power spectrum
    log_power_spectrum = np.log(power_spectrum + np.finfo(float).eps)

    # Compute the inverse Fourier transform of the log power spectrum (Cepstrum)
    cepstrum = np.fft.ifft(log_power_spectrum, axis=0).real

    return cepstrum

def save_cepstrum_as_image(cepstrum, output_path, target_size=(256, 43)):
    # Plot the cepstrum
    plt.figure(figsize=(10, 4))
    plt.imshow(cepstrum, aspect='auto', origin='lower')
    plt.colorbar()
    plt.title('Cepstrum')
    plt.tight_layout()

    # Save the plot as an image
    plt.savefig(output_path, format='png')
    plt.close()

    # Resize the image to the target size
    with Image.open(output_path) as img:
        img = img.resize(target_size, Image.ANTIALIAS)
        img.save(output_path)

def process_audio_file(audio_file, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(256, 43)):
    y, sr = librosa.load(audio_file, sr=sr)
    
    segment_samples = int(segment_length * sr)
    frame_samples = int(frame_length * sr)
    hop_samples = int(hop_length * sr)

    base_filename = os.path.splitext(os.path.basename(audio_file))[0]
    file_output_folder = os.path.join(output_folder, base_filename)
    os.makedirs(file_output_folder, exist_ok=True)

    for i in range(0, len(y), segment_samples):
        segment = y[i:i + segment_samples]
        if len(segment) < segment_samples:
            break
        
        # Extract cepstrum for each frame in the segment
        cepstrum = extract_cepstrum(segment, sr, frame_length, hop_length)
        
        # Save the cepstrum as an image
        output_filename = os.path.join(file_output_folder, f"{base_filename}_segment_{i//segment_samples + 1}.png")
        save_cepstrum_as_image(cepstrum, output_filename, target_size)
        print(f'Saved image: {output_filename}')

def process_folder(input_folder, output_folder, sr=16000, segment_length=3, frame_length=0.25, hop_length=0.064, target_size=(256, 43)):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)
    
    # Process each .wav file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.wav'):
            audio_file = os.path.join(input_folder, filename)
            process_audio_file(audio_file, output_folder, sr, segment_length, frame_length, hop_length, target_size)

# Process audio files
process_folder(input_folder, output_folder)
# Out:
# /tmp/ipykernel_34/896674803.py:36: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)
# Saved image: /kaggle/working/Tanker-CEPSTRUM/33/33_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/33/33_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/33/33_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/33/33_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/33/33_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_7.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_8.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_9.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_10.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_11.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_12.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_13.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_14.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_15.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_16.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_17.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_18.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_19.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_20.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_21.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_22.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_23.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_24.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_25.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_26.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_27.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_28.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_29.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_30.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_31.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_32.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_33.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_34.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_35.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_36.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_37.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_38.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_39.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_40.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_41.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_42.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_43.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_44.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_45.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_46.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_47.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_48.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_49.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_50.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_51.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_52.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_53.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_54.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_55.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_56.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/6/6_segment_57.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_7.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/14/14_segment_8.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/19/19_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/19/19_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/19/19_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/19/19_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_7.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_8.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_9.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_10.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_11.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_12.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_13.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_14.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_15.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_16.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_17.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_18.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_19.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_20.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_21.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_22.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_23.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_24.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_25.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_26.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_27.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_28.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_29.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_30.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_31.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_32.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_33.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/20/20_segment_34.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/9/9_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_7.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_8.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_9.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_10.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_11.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_12.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_13.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_14.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/5/5_segment_15.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/21/21_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/21/21_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/21/21_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/21/21_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/21/21_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_1.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_2.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_3.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_4.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_5.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_6.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_7.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_8.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_9.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_10.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_11.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_12.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_13.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_14.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_15.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_16.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_17.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_18.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_19.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_20.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_21.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_22.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_23.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_24.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_25.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_26.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_27.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_28.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_29.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_30.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_31.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_32.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_33.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_34.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_35.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_36.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_37.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_38.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment_39.png
# Saved image: /kaggle/working/Tanker-CEPSTRUM/39/39_segment